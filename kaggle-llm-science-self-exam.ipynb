# %% [markdown]
# using BERT to rank the best answer from generated questions. we will finetune BERT to answer 200 public questions, then use the AutoModelForMultipleChoice class to generate probabilities that each option correctly answers the prompt, and finally we'll turn those predictions into a MAP@3-formatted prediction like A B C.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

train_df = pd.read_csv('/kaggle/input/kaggle-llm-science-exam/train.csv')
train_df.head()


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
#    id                                             prompt  \
# 0   0  Which of the following statements accurately d...
# 1   1  Which of the following is an accurate definiti...
# 2   2  Which of the following statements accurately d...
# 3   3  What is the significance of regularization in ...
# 4   4  Which of the following statements accurately d...
#
#                                                    A  \
# 0  MOND is a theory that reduces the observed mis...
# 1  Dynamic scaling refers to the evolution of sel...
# 2  The triskeles symbol was reconstructed as a fe...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    B  \
# 0  MOND is a theory that increases the discrepanc...
# 1  Dynamic scaling refers to the non-evolution of...
# 2  The triskeles symbol is a representation of th...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    C  \
# 0  MOND is a theory that explains the missing bar...
# 1  Dynamic scaling refers to the evolution of sel...
# 2  The triskeles symbol is a representation of a ...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    D  \
# 0  MOND is a theory that reduces the discrepancy ...
# 1  Dynamic scaling refers to the non-evolution of...
# 2  The triskeles symbol represents three interloc...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    E answer
# 0  MOND is a theory that eliminates the observed ...      D
# 1  Dynamic scaling refers to the evolution of sel...      A
# 2  The triskeles symbol is a representation of th...      A
# 3  Regularizing the mass-energy of an electron wi...      C
# 4  The angular spacing of features in the diffrac...      D

# %%
# Turning previous pandas Dataframe into a Dataset
from datasets import Dataset
train_ds = Dataset.from_pandas(train_df)

# %%
from transformers import AutoTokenizer

# The model path we will use
model_dir = '/kaggle/input/huggingface-bert/bert-base-cased'
tokenizer = AutoTokenizer.from_pretrained(model_dir)

# %%
# Converting answer options into indices and back again
options = 'ABCDE'
indices = list(range(5))

option_to_index = {option: index for option, index in zip(options, indices)}
index_to_option = {index: option for option, index in zip(options, indices)}

def preprocess(example):
    # Copying questions 5 times before tokenizing
    first_sentence = [example['prompt']] * 5
    second_sentence = []
    for option in options:
        second_sentence.append(example[option])
    # Tokenizer turning text into token IDs
    tokenized_example = tokenizer(first_sentence, second_sentence, truncation=True)
    tokenized_example['label'] = option_to_index[example['answer']]
    return tokenized_example

tokenized_train_ds = train_ds.map(preprocess, batched=False, remove_columns=['prompt', 'A', 'B', 'C', 'D', 'E', 'answer'])
# Out:
#   0%|          | 0/200 [00:00<?, ?ex/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
# Dynamically padding the questions at batch-time
from dataclasses import dataclass
from transformers.tokenization_utils_base import PreTrainedTokenizerBase, PaddingStrategy
from typing import Optional, Union
import torch

@dataclass
class DataCollatorForMultipleChoice:
    tokenizer: PreTrainedTokenizerBase
    padding: Union[bool, str, PaddingStrategy] = True
    max_length: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
        
    def __call__(self, features):
        label_name = 'label' if 'label' in features[0].keys() else 'labels'
        labels = [feature.pop(label_name) for feature in features]
        batch_size = len(features)
        num_choices = len(features[0]['input_ids'])
        flattened_features = [
            [{k: v[i] for k, v in feature.items()} for i in range(num_choices)] for feature in features
        ]
        flattened_features = sum(flattened_features, [])
        
        batch = self.tokenizer.pad(
            flattened_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors='pt',
        )
        
        batch = {k: v.view(batch_size, num_choices, -1) for k, v in batch.items()}
        batch['labels'] = torch.tensor(labels, dtype=torch.int64)
        return batch

# %%
# Instatiating the model
from transformers import AutoModelForMultipleChoice, TrainingArguments, Trainer
model = AutoModelForMultipleChoice.from_pretrained(model_dir)
# Out:
# Some weights of BertForMultipleChoice were not initialized from the model checkpoint at /kaggle/input/huggingface-bert/bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Finetune arguments
model_dir = 'finetuned_bert'
training_args = TrainingArguments(
    output_dir=model_dir,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    learning_rate=5e-4,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.015,
    report_to='none'
)

# %%
# Train and validate on training set
trainer = Trainer(
model=model,
args=training_args,
train_dataset=tokenized_train_ds,
eval_dataset=tokenized_train_ds,
tokenizer=tokenizer,
data_collator=DataCollatorForMultipleChoice(tokenizer=tokenizer)
)

# %%
trainer.train()
# Out:
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 27:58, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.609438</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.609438</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.609438</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=150, training_loss=1.621434834798177, metrics={'train_runtime': 1687.7401, 'train_samples_per_second': 0.356, 'train_steps_per_second': 0.089, 'total_flos': 134904871258320.0, 'train_loss': 1.621434834798177, 'epoch': 3.0})

# %%
# Making predictions
predictions = trainer.predict(tokenized_train_ds)

# %%
# Get highest scoring answer and returning to default format
import numpy as np
def predictions_to_map_output(predictions):
    sorted_answer_indices = np.argsort(-predictions)
    top_answer_indices = sorted_answer_indices[:,:3]
    top_answers = np.vectorize(index_to_option.get)(top_answer_indices)
    return np.apply_along_axis(lambda row: ' '.join(row), 1, top_answers)

# %%
predictions_to_map_output(predictions.predictions)
# Out:
# array(['B D A', 'D C B', 'B E C', 'D C A', 'C E D', 'B C D', 'C B D',
#        'E B D', 'A B C', 'A B C', 'B A C', 'A D B', 'C A B', 'E A C',
#        'A D B', 'E C D', 'D E B', 'A D C', 'A D E', 'E C B', 'B D E',
#        'D E C', 'C A B', 'B C A', 'E A B', 'E A C', 'A B E', 'A E D',
#        'B E A', 'C A E', 'D A B', 'C D A', 'E B D', 'E D A', 'C A E',
#        'E B A', 'B E C', 'A B D', 'E D B', 'B A E', 'A E B', 'A B D',
#        'B C A', 'D C E', 'A B D', 'A D B', 'E B A', 'C D E', 'E B C',
#        'D E B', 'D B E', 'C B E', 'E D B', 'E A B', 'C D E', 'E B C',
#        'A B D', 'B C A', 'A D E', 'B C A', 'B C A', 'D C A', 'D E A',
#        'A C E', 'D A C', 'A C B', 'C E B', 'A E C', 'C E A', 'C D E',
#        'B A D', 'B D A', 'C E D', 'E B D', 'A E C', 'B E A', 'A C D',
#        'E D A', 'C B D', 'E A B', 'C D B', 'D B C', 'D B E', 'B A D',
#        'B A C', 'E C D', 'B C E', 'E C A', 'D B E', 'C E A', 'B D C',
#        'B A E', 'D C A', 'E A C', 'D C A', 'C A E', 'D A B', 'B D E',
#        'C B D', 'E A B', 'E C D', 'B A E', 'B D C', 'E D A', 'A C B',
#        'D B A', 'A E D', 'E A B', 'A C D', 'C D E', 'A B D', 'B E C',
#        'C B D', 'C B D', 'D C A', 'A E D', 'A E B', 'A C D', 'B A D',
#        'C B A', 'A C D', 'A D C', 'B C E', 'E B A', 'B A D', 'B C E',
#        'E A B', 'C A E', 'E B D', 'A C E', 'B A E', 'A B C', 'A C E',
#        'C B E', 'D C B', 'C B A', 'E D B', 'A D B', 'C E B', 'B C E',
#        'C B D', 'D E A', 'B A C', 'A D E', 'B D C', 'E D A', 'D C B',
#        'E B C', 'C A E', 'D B A', 'A D B', 'C E A', 'B A D', 'B A C',
#        'D E A', 'A D C', 'B D C', 'A C D', 'E A D', 'D B C', 'B A E',
#        'C B E', 'A E B', 'B A C', 'E C A', 'D C A', 'B A C', 'D A E',
#        'C B E', 'A B C', 'B C D', 'B A E', 'C E A', 'C D B', 'A B D',
#        'C E A', 'E A B', 'D C B', 'E A B', 'C E A', 'A B D', 'C D E',
#        'C E D', 'E A D', 'D C E', 'E D A', 'D B A', 'A D E', 'C D B',
#        'B E C', 'D A E', 'D C E', 'A B E', 'B C A', 'E D A', 'C B D',
#        'A D B', 'C A B', 'B C D', 'B A E'], dtype='<U5')

# %%
# Load the test Dataframe
test_df = pd.read_csv('/kaggle/input/kaggle-llm-science-exam/test.csv')
test_df.head()
# Out:
#    id                                             prompt  \
# 0   0  Which of the following statements accurately d...
# 1   1  Which of the following is an accurate definiti...
# 2   2  Which of the following statements accurately d...
# 3   3  What is the significance of regularization in ...
# 4   4  Which of the following statements accurately d...
#
#                                                    A  \
# 0  MOND is a theory that reduces the observed mis...
# 1  Dynamic scaling refers to the evolution of sel...
# 2  The triskeles symbol was reconstructed as a fe...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    B  \
# 0  MOND is a theory that increases the discrepanc...
# 1  Dynamic scaling refers to the non-evolution of...
# 2  The triskeles symbol is a representation of th...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    C  \
# 0  MOND is a theory that explains the missing bar...
# 1  Dynamic scaling refers to the evolution of sel...
# 2  The triskeles symbol is a representation of a ...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    D  \
# 0  MOND is a theory that reduces the discrepancy ...
# 1  Dynamic scaling refers to the non-evolution of...
# 2  The triskeles symbol represents three interloc...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...
#
#                                                    E
# 0  MOND is a theory that eliminates the observed ...
# 1  Dynamic scaling refers to the evolution of sel...
# 2  The triskeles symbol is a representation of th...
# 3  Regularizing the mass-energy of an electron wi...
# 4  The angular spacing of features in the diffrac...

# %%
# Tokenize test dataset
test_df['answer'] = 'A'

test_ds = Dataset.from_pandas(test_df)
tokenized_test_ds = test_ds.map(preprocess, batched=False, remove_columns=['prompt', 'A', 'B', 'C', 'D', 'E', 'answer'])
# Out:
#   0%|          | 0/200 [00:00<?, ?ex/s]

# %%
# Generating predictons
test_predictions = trainer.predict(tokenized_test_ds)

# %%
# Submission file
submission_df = test_df[['id']]
submission_df['prediction'] = predictions_to_map_output(test_predictions.predictions)

submission_df.head()
# Out:
# /tmp/ipykernel_20/1041267606.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission_df['prediction'] = predictions_to_map_output(test_predictions.predictions)
#    id prediction
# 0   0      B D A
# 1   1      D C B
# 2   2      B E C
# 3   3      D C A
# 4   4      C E D

# %%
submission_df.to_csv('submission.csv', index=False)
